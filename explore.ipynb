# %%
import pandas as pd
from glob import glob

# %%
files = glob('data/*.csv')
df_list = [pd.read_csv(file) for file in files]
df = pd.concat(df_list)
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 705621 entries, 0 to 239999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   RestaurantName  705621 non-null  object
#  1   Cuisine         705607 non-null  object
#  2   OpenHours       463511 non-null  object
#  3   State           705621 non-null  object
#  4   CNTY_GEOID      705621 non-null  int64
#  5   CNTY_NAME       705621 non-null  object
#  6   UA_GEOID        631864 non-null  float64
#  7   UA_NAME         631864 non-null  object
#  8   MSA_GEOID       613885 non-null  float64
#  9   MSA_NAME        613885 non-null  object
#  10  Lon             705621 non-null  float64
#  11  Lat             705621 non-null  float64
#  12  Frequency       705621 non-null  int64
#  13  isChain         705621 non-null  int64
# dtypes: float64(4), int64(3), object(7)
# memory usage: 80.8+ MB
#        RestaurantName               Cuisine  \
# ...

# %%
df = df[(df['State'] == 'OR') & (df['CNTY_NAME'] == 'Multnomah')]
df
# Out:
#                    RestaurantName              Cuisine  \
# 519                        GoPuff           Restaurant
# 1271                 Burger Bytes           Restaurant
# 1278                 Burger Bytes           Restaurant
# 1324                Cinco De Mayo           Restaurant
# 1508                Dragon Palace  Chinese Sushi Asian
# ...                           ...                  ...
# 237779               Veggie Grill   American Fast Food
# 237901                Bella Pizza      Italian Bar Pub
# 239294  The Old Spaghetti Factory     Italian American
# 239408               Bamboo House           Restaurant
# 239911                 Loving Hut                Asian
#
#                                                 OpenHours State  CNTY_GEOID  \
# 519                                                   NaN    OR       41051
# 1271                                                  NaN    OR       41051
# ...

# %%
df['isChain'].describe()
# Out:
# count    3463.000000
# mean        0.231302
# std         0.421726
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: isChain, dtype: float64
